# %% [markdown]
# # Correlation Analysis: Prelude to Calibration
#
#
# Correlation analysis, despite its simplicity and many shortcomings, remains a centerpiece of empirical analysis in many fields, particularly the paleosciences. Computing correlations is trivial enough; the difficulty lies in properly assessing their significance. Of particular importance are three considerations:
#
# - Persistence, which violates the standard assumption that the data are independent (which underlies the classical test of significance implemented, e.g. in Excel).
# - Time irregularities, for instance comparing two records with different time axes, possibly unevenly spaced (which standard software cannot deal with out of the box)
# - Age uncertainties for example comparing two records, each with an ensemble of plausible chronologies (generated, for instance, by a Bayesian age model)
# - Test multiplicity aka the "Look Elsewhere effect", which states that repeatedly performing the same test can result in unacceptably high type I error (accepting correlations as significant, when in fact they are not). This arises e.g. when correlating a paleoclimate record with an instrumental field, assessing significance at thounsands of grid points at once, or assessing significance within an age ensemble.
#
# Accordingly,  Pyleoclim facilitates an assessment of correlations that deals with all these cases, makes the necessary data transformations transparent to the user, and allows for one-line plot commands to visualize the results.
#
# In this notebook we reproduce the case of [Hu et al, 2017](http://dx.doi.org/10.1016/j.epsl.2016.11.048), particularly the example of their section 4, which illustrates several of these pitfalls at once.  The example uses the speleothem record of [McCabe-Glynn et al , 2013](https://www.nature.com/articles/ngeo1862).

# %%
# %load_ext autoreload
# %autoreload 2
    
import pyleoclim as pyleo
import numpy as np
import xarray as xr
# Out:
# [autoreload of pandas._config.config failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     ref.__class__ = new
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/_config/config.py", line 198, in __setattr__
#     raise OptionError("You can only set the value of existing options")
# pandas._config.config.OptionError: 'You can only set the value of existing options'
# ]
# [autoreload of pandas.core.nanops failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: nanstd() requires a code object with 2 free vars, not 4
# ]
# [autoreload of pandas.core.arrays.boolean failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __and___() requires a code object with 1 free vars, not 2
# ]
# [autoreload of pandas.core.accessor failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __dir__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.arrays.categorical failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/arrays/categorical.py", line 56, in <module>
#     from pandas.core.strings.object_array import ObjectStringArrayMixin
# ModuleNotFoundError: No module named 'pandas.core.strings.object_array'; 'pandas.core.strings' is not a package
# ]
# [autoreload of pandas.core.arrays.datetimelike failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __getitem__() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.arrays.integer failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: sum() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.arrays.sparse.array failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __pos__() requires a code object with 2 free vars, not 0
# ]
# [autoreload of pandas.core.indexes.base failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __add__() requires a code object with 0 free vars, not 2
# ]
# [autoreload of pandas.core.arrays.interval failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/arrays/interval.py", line 10, in <module>
#     from pandas._libs.interval import (
# ImportError: cannot import name 'VALID_CLOSED' from 'pandas._libs.interval' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/_libs/interval.cpython-38-darwin.so)
# ]
# [autoreload of pandas.core.arrays.numpy_ failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/arrays/numpy_.py", line 17, in <module>
#     from pandas.core.strings.object_array import ObjectStringArrayMixin
# ModuleNotFoundError: No module named 'pandas.core.strings.object_array'; 'pandas.core.strings' is not a package
# ]
# [autoreload of pandas.core.arrays.string_ failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/arrays/string_.py", line 21, in <module>
#     from pandas.core.arrays import FloatingArray, IntegerArray, PandasArray
# ImportError: cannot import name 'FloatingArray' from 'pandas.core.arrays' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/arrays/__init__.py)
# ]
# [autoreload of pandas.core.indexes.category failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: duplicated() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.indexes.numeric failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __neg__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pandas.core.indexes.datetimelike failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: delete() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.indexes.datetimes failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: to_perioddelta() requires a code object with 2 free vars, not 0
# ]
# [autoreload of pandas.core.indexes.multi failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 340, in <lambda>
#     lambda a, b: update_function(a.__func__, b.__func__)),
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: from_tuples() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.indexes.timedeltas failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: all() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pandas.core.indexes.interval failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: func() requires a code object with 2 free vars, not 0
# ]
# [autoreload of pandas.core.indexes.period failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: asof_locs() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.core.indexes.range failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: intersection() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pandas.core.indexing failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/indexing.py", line 9, in <module>
#     from pandas._libs.indexing import NDFrameIndexerBase
# ImportError: cannot import name 'NDFrameIndexerBase' from 'pandas._libs.indexing' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/_libs/indexing.cpython-38-darwin.so)
# ]
# [autoreload of pandas.core.internals.blocks failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: __init__() requires a code object with 1 free vars, not 0
# ]
# [autoreload of pandas.core.tools.datetimes failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/tools/datetimes.py", line 29, in <module>
#     from pandas._libs.tslibs.parsing import (  # noqa
# ImportError: cannot import name 'format_is_iso' from 'pandas._libs.tslibs.parsing' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/_libs/tslibs/parsing.cpython-38-darwin.so)
# ]
# [autoreload of pandas.core.window.rolling failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/window/rolling.py", line 51, in <module>
#     from pandas.core.aggregation import aggregate
# ImportError: cannot import name 'aggregate' from 'pandas.core.aggregation' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/aggregation.py)
# ]
# [autoreload of pandas.core.window.ewm failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/window/ewm.py", line 30, in <module>
#     from pandas.core.window.rolling import BaseWindow, BaseWindowGroupby, dispatch
# ImportError: cannot import name 'BaseWindow' from 'pandas.core.window.rolling' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/window/rolling.py)
# ]
# [autoreload of pandas.core.window.expanding failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/window/expanding.py", line 12, in <module>
#     from pandas.core.window.rolling import BaseWindowGroupby, RollingAndExpandingMixin
# ImportError: cannot import name 'BaseWindowGroupby' from 'pandas.core.window.rolling' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/window/rolling.py)
# ]
# [autoreload of pandas.core.window failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/window/__init__.py", line 1, in <module>
#     from pandas.core.window.ewm import (  # noqa:F401
# ImportError: cannot import name 'ExponentialMovingWindowGroupby' from 'pandas.core.window.ewm' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/window/ewm.py)
# ]
# [autoreload of pandas.core.series failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/series.py", line 72, in <module>
#     from pandas.core.aggregation import aggregate, transform
# ImportError: cannot import name 'aggregate' from 'pandas.core.aggregation' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/core/aggregation.py)
# ]
# [autoreload of pandas.core.frame failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: sort_index() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.io.parsers failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 302, in update_class
#     if update_generic(old_obj, new_obj): continue
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 266, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: close() requires a code object with 0 free vars, not 1
# ]
# [autoreload of pandas.io.excel._odfreader failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_odfreader.py", line 10, in <module>
#     from pandas.io.excel._base import BaseExcelReader
# ImportError: cannot import name 'BaseExcelReader' from 'pandas.io.excel._base' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_base.py)
# ]
# [autoreload of pandas.io.excel._openpyxl failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py", line 8, in <module>
#     from pandas.io.excel._base import BaseExcelReader, ExcelWriter
# ImportError: cannot import name 'BaseExcelReader' from 'pandas.io.excel._base' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_base.py)
# ]
# [autoreload of pandas.io.excel._pyxlsb failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_pyxlsb.py", line 6, in <module>
#     from pandas.io.excel._base import BaseExcelReader
# ImportError: cannot import name 'BaseExcelReader' from 'pandas.io.excel._base' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_base.py)
# ]
# [autoreload of pandas.io.excel._xlrd failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_xlrd.py", line 8, in <module>
#     from pandas.io.excel._base import BaseExcelReader
# ImportError: cannot import name 'BaseExcelReader' from 'pandas.io.excel._base' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_base.py)
# ]
# [autoreload of pandas.io.excel._base failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_base.py", line 973, in <module>
#     class ExcelFile:
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_base.py", line 1018, in ExcelFile
#     from pandas.io.excel._odfreader import ODFReader
# ImportError: cannot import name 'ODFReader' from 'pandas.io.excel._odfreader' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_odfreader.py)
# ]
# [autoreload of pandas.io.excel failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/__init__.py", line 3, in <module>
#     from pandas.io.excel._openpyxl import OpenpyxlWriter as _OpenpyxlWriter
# ImportError: cannot import name 'OpenpyxlWriter' from 'pandas.io.excel._openpyxl' (/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/io/excel/_openpyxl.py)
# ]
# [autoreload of pandas._testing failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/pandas/_testing.py", line 3054, in <module>
#     cython_table = pd.core.base.SelectionMixin._cython_table.items()
# AttributeError: module 'pandas.core' has no attribute 'base'
# ]
# [autoreload of psutil._psosx failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/psutil/_psosx.py", line 38, in <module>
#     PAGESIZE = cext_posix.getpagesize()
# AttributeError: module 'psutil._psutil_posix' has no attribute 'getpagesize'
# ]
# [autoreload of psutil failed: Traceback (most recent call last):
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 604, in _exec
#   File "<frozen importlib._bootstrap_external>", line 783, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/psutil/__init__.py", line 239, in <module>
#     raise ImportError(msg)
# ImportError: version conflict: '/Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/psutil/_psutil_osx.cpython-38-darwin.so' C extension module was built for another version of psutil (5.7.2 instead of 5.8.0); you may try to 'pip uninstall psutil', manually remove /Users/julieneg/opt/miniconda3/envs/pyleo/lib/python3.8/site-packages/psutil/_psutil_osx.cpython-38-darwin.so or clean the virtual env somehow, then reinstall
# ]

# %% [markdown]
# We first load SST data

# %%
url = 'https://psl.noaa.gov/thredds/dodsC/Datasets/noaa.ersst.v5/sst.mnmean.nc'
with xr.open_d
